# %%
import pandas as pd

# %%
data_dir="../data/education-data/processed"
df_data=pd.read_csv(f"{data_dir}/melted_output.csv",nrows=1000)

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    1000 non-null   object
#  1   Country Code    1000 non-null   object
#  2   Indicator Name  1000 non-null   object
#  3   Indicator Code  1000 non-null   object
#  4   Year            1000 non-null   int64
#  5   Value           12 non-null     float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 47.0+ KB
